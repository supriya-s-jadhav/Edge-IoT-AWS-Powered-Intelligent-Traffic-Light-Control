# %% [markdown]
# ## Edge demo Model 01 : TrafficLight Simulator Example
# 1. Impirt necessary libraries
# 2. Create S3 bucket
# 3. Mapping train and test data in S3
# 4. Mapping the path of the models in S3

# %%
# Import libraries
import sagemaker
import boto3
from sagemaker.session import s3_input, Session
from sagemaker.amazon.amazon_estimator import get_image_uri
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
bucket_name = 'edge-demo-sagemaker-model'
my_region = boto3.session.Session().region_name
print(my_region)
# Out:
# us-east-1

# %%
s3 = boto3.resource('s3')
try:
    if my_region == 'us-east-1':
        s3.create_bucket(Bucket=bucket_name)
    print('S3 bucket created successfully')
except Exception as e:
    print('S3 error : ', e)
# Out:
# S3 bucket created successfully

# %%
# set an output path where the trained model will be saved
prefix = 'xgboost-as-a-built-in-algo'
output_path = 's3://{}/{}/output'.format(bucket_name, prefix)
print(output_path)
# Out:
# s3://edge-demo-sagemaker-model/xgboost-as-a-built-in-algo/output

# %% [markdown]
# ### Read data stored in s3 bucket

# %%
data_key ='carStats.csv'
data_location = 's3://{}/{}'.format(bucket_name,data_key)
traffic_data = pd.read_csv(data_location)

# %%
traffic_data.head(2)
# Out:
#    totalgreenlights                        time  mincarspassing  totaltraffic  \
# 0                18  2021-03-19 08:25:05.086367               1           194
# 1                36  2021-03-19 08:34:05.479790               1           352
#
#    maxcarspassing
# 0              20
# 1              20

# %%
traffic_data.columns = ['TotalGreenlights (N)', 'Time (S)', 'MinCarsPassing (N)',  'OUTPUT_LABEL','MaxCarsPassing (N)']
traffic_data.head(2)
# Out:
#    TotalGreenlights (N)                    Time (S)  MinCarsPassing (N)  \
# 0                    18  2021-03-19 08:25:05.086367                   1
# 1                    36  2021-03-19 08:34:05.479790                   1
#
#    OUTPUT_LABEL  MaxCarsPassing (N)
# 0           194                  20
# 1           352                  20

# %%
traffic_data = traffic_data[['OUTPUT_LABEL','MaxCarsPassing (N)','TotalGreenlights (N)','MinCarsPassing (N)']]
traffic_data.head(2)
# Out:
#    OUTPUT_LABEL  MaxCarsPassing (N)  TotalGreenlights (N)  MinCarsPassing (N)
# 0           194                  20                    18                   1
# 1           352                  20                    36                   1

# %% [markdown]
# ### Split data into train and test dataset

# %%
train_data, test_data = np.split(traffic_data.sample(frac=1,random_state=1729),[int(0.7*len(traffic_data))])
print(train_data.shape, test_data.shape)
# Out:
# (11, 4) (5, 4)

# %% [markdown]
# ### Save train and test data into s3 buckets

# %%
## save train data into s3 bucket
train_data.to_csv('train_data.csv', index=False, header=False)
boto3.Session().resource('s3').Bucket(bucket_name).Object(os.path.join(prefix, 'train/train_data.csv')).upload_file('train_data.csv')
s3_input_train = sagemaker.TrainingInput(s3_data='s3://{}/{}/train'.format(bucket_name, prefix), content_type='csv')

# %%
## save test data into s3 bucket
test_data.to_csv('test_data.csv', index=False, header=False)
boto3.Session().resource('s3').Bucket(bucket_name).Object(os.path.join(prefix,'test/test_data.csv')).upload_file('test_data.csv')
s3_input_test = sagemaker.TrainingInput(s3_data='s3://{}/{}/test'.format(bucket_name, prefix), content_type='csv')

# %% [markdown]
# ### Model building : XGBoost Classifier

# %%
# this line automatically looks for the XGBoost image URI and builds an XGBoost container.
# specify the repo_version depending on your preference.

xgboost_container = get_image_uri(boto3.Session().region_name, 'xgboost', repo_version='1.0-1')
# Out:
# The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
# initialize hyperparameter

hyperparameters = {
        "max_depth":"5",
        "eta":"0.2",
        "gamma":"4",
        "min_child_weight":"6",
        "subsample":"0.7",
        "objective":"reg:linear",
        "num_round":"50"}

# %%
# construct a SageMaker estimator that calls the xgboost-container
estimator = sagemaker.estimator.Estimator(image_uri=xgboost_container, 
                                          hyperparameters=hyperparameters,
                                          role=sagemaker.get_execution_role(),
                                          instance_count=1, 
                                          instance_type='ml.m5.2xlarge', 
                                          volume_size=5, # 5 GB 
                                          output_path=output_path,
                                          train_use_spot_instances=True,
                                          train_max_run=300,
                                          train_max_wait=600)
# Out:
# train_max_run has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_use_spot_instances has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_max_wait has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
estimator.fit({'train': s3_input_train, 'validation': s3_input_test})
# Out:
# 2021-04-06 06:45:53 Starting - Starting the training job...
# 2021-04-06 06:45:54 Starting - Launching requested ML instancesProfilerReport-1617691552: InProgress
# ......
# 2021-04-06 06:47:20 Starting - Preparing the instances for training...
# 2021-04-06 06:47:53 Downloading - Downloading input data
# 2021-04-06 06:47:53 Training - Downloading the training image.....INFO:sagemaker-containers:Imported framework sagemaker_xgboost_container.training
# INFO:sagemaker-containers:Failed to parse hyperparameter objective value reg:linear to Json.
# Returning the value itself
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker_xgboost_container.training:Running XGBoost Sagemaker in algorithm mode
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# [06:48:27] 11x3 matrix with 33 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# INFO:root:Determined delimiter of CSV input is ','
# [06:48:27] 5x3 matrix with 15 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# INFO:root:Single node training.
# INFO:root:Train matrix has 11 rows
# INFO:root:Validation matrix has 5 rows
# [06:48:27] WARNING: /workspace/src/objective/regression_obj.cu:167: reg:linear is now deprecated in favor of reg:squarederror.
# [06:48:27] WARNING: /workspace/src/learner.cc:328:
# Parameters: { num_round } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]#011train-rmse:235.99734#011validation-rmse:314.51837
# [1]#011train-rmse:214.95174#011validation-rmse:290.20071
# [2]#011train-rmse:193.05592#011validation-rmse:263.58600
# [3]#011train-rmse:172.76657#011validation-rmse:236.76982
# [4]#011train-rmse:159.32217#011validation-rmse:216.74953
# [5]#011train-rmse:150.09877#011validation-rmse:200.84154
# [6]#011train-rmse:144.96928#011validation-rmse:190.43127
# [7]#011train-rmse:139.65457#011validation-rmse:176.91086
# [8]#011train-rmse:138.27664#011validation-rmse:172.38078
# [9]#011train-rmse:138.96408#011validation-rmse:174.73193
# [10]#011train-rmse:137.55196#011validation-rmse:169.63046
# [11]#011train-rmse:136.83800#011validation-rmse:166.50438
# [12]#011train-rmse:137.09753#011validation-rmse:167.70306
# [13]#011train-rmse:136.79869#011validation-rmse:166.31519
# [14]#011train-rmse:136.06784#011validation-rmse:162.25513
# [15]#011train-rmse:135.48303#011validation-rmse:157.24092
# [16]#011train-rmse:135.37453#011validation-rmse:155.60580
# [17]#011train-rmse:135.30719#011validation-rmse:153.89209
# [18]#011train-rmse:135.39653#011validation-rmse:155.99530
# [19]#011train-rmse:135.32571#011validation-rmse:154.50569
# [20]#011train-rmse:135.44623#011validation-rmse:156.75299
# [21]#011train-rmse:135.29056#011validation-rmse:152.88452
# [22]#011train-rmse:135.46532#011validation-rmse:157.01216
# [23]#011train-rmse:135.60535#011validation-rmse:158.60509
# [24]#011train-rmse:135.77850#011validation-rmse:160.15736
# [25]#011train-rmse:135.79657#011validation-rmse:160.30304
# [26]#011train-rmse:135.59189#011validation-rmse:158.46921
# [27]#011train-rmse:135.28978#011validation-rmse:152.09764
# [28]#011train-rmse:135.33888#011validation-rmse:150.06815
# [29]#011train-rmse:135.38724#011validation-rmse:149.13193
# [30]#011train-rmse:135.41499#011validation-rmse:148.70308
# [31]#011train-rmse:135.34203#011validation-rmse:149.99554
# [32]#011train-rmse:135.43384#011validation-rmse:148.43938
# [33]#011train-rmse:135.45032#011validation-rmse:148.22307
# [34]#011train-rmse:135.29279#011validation-rmse:153.11069
# [35]#011train-rmse:135.32022#011validation-rmse:150.55527
# [36]#011train-rmse:135.43909#011validation-rmse:148.36919
# [37]#011train-rmse:135.60817#011validation-rmse:146.56215
# [38]#011train-rmse:135.44266#011validation-rmse:148.32214
# [39]#011train-rmse:136.07277#011validation-rmse:143.38840
# [40]#011train-rmse:135.78369#011validation-rmse:145.17700
# [41]#011train-rmse:135.45984#011validation-rmse:148.10352
# [42]#011train-rmse:135.61085#011validation-rmse:146.53815
# [43]#011train-rmse:135.30225#011validation-rmse:151.20091
# [44]#011train-rmse:135.60751#011validation-rmse:146.56790
# [45]#011train-rmse:135.60288#011validation-rmse:146.60953
# [46]#011train-rmse:135.33681#011validation-rmse:150.11688
# [47]#011train-rmse:135.29292#011validation-rmse:153.12277
# [48]#011train-rmse:135.43758#011validation-rmse:156.63043
# [49]#011train-rmse:135.38805#011validation-rmse:155.85010
#
# 2021-04-06 06:48:41 Uploading - Uploading generated training model
# 2021-04-06 06:48:41 Completed - Training job completed
# Training seconds: 53
# Billable seconds: 22
# Managed Spot Training savings: 58.5%

# %% [markdown]
# ### Making Inference : Deploy Machine Learning Model As Ednpoints

# %%
# Generating the endpoint for the deployment
xgb_predictor = estimator.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
# Out:
# -----------------!

# %%
cols_input = ['MaxCarsPassing (N)', 'TotalGreenlights (N)', 'MinCarsPassing (N)']
test_data_array = test_data[cols_input]
#t.columns = ['f0', 'f1', 'f2']

# %%
from sagemaker.predictor import csv_serializer
from sagemaker.xgboost.estimator import XGBoost
# Install training algorithm if it is not instalpip install xgboost
# !type python3
# !/home/ec2-user/anaconda3/envs/python3/bin/python3 -m pip install xgboost==0.90
import xgboost as xgb
# Out:
# python3 is /home/ec2-user/anaconda3/envs/python3/bin/python3
# Collecting xgboost==0.90
#   Downloading xgboost-0.90-py2.py3-none-manylinux1_x86_64.whl (142.8 MB)
#      |████████████████████████████████| 142.8 MB 16 kB/s s eta 0:00:01    |██████████▎                     | 45.9 MB 15.3 MB/s eta 0:00:07     |██████████████████████████▊     | 119.4 MB 65.0 MB/s eta 0:00:01
# Requirement already satisfied: scipy in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from xgboost==0.90) (1.5.3)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from xgboost==0.90) (1.19.5)
# Installing collected packages: xgboost
# Successfully installed xgboost-0.90

# %%
#xgb_predictor.content_type = 'text/csv' # set the data type for an inference
xgb_predictor.serializer = csv_serializer # set the serializer type

# %%
predictions = xgb_predictor.predict(test_data_array.values).decode('utf-8') # predict!
predictions_array = np.fromstring(predictions[:],sep=',')
predictions_array = pd.DataFrame(predictions_array) # and turn the prediction into an array
# Out:
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
t1= test_data[['OUTPUT_LABEL']]
t2= predictions_array
results = pd.concat([t1, t2], axis=1)

#compare_results

# %%
#cm = pd.crosstab(index=test_data['OUTPUT_LABEL'], columns=np.round(predictions_array), rownames=['Observed'], colnames=['Predicted'])
#tn = cm.iloc[0,0]
#fn = cm.iloc[1,0]
#tp = cm.iloc[1,1]
#fp = cm.iloc[0,1]
#p = (tp+tn)/(tp+tn+fp+fn)*100
#print("\n{0:<20}{1:<4.1f}%\n".format("Overall Classification Rate: ", p))
#print("{0:<15}{1:<15}{2:>8}".format("Predicted", "No Purchase", "Purchase"))
#print("Observed")
#print("{0:<15}{1:<2.0f}% ({2:<}){3:>6.0f}% ({4:<})".format("No Purchase", tn/(tn+fn)*100,tn, fp/(tp+fp)*100, fp))
#print("{0:<16}{1:<1.0f}% ({2:<}){3:>7.0f}% ({4:<}) \n".format("Purchase", fn/(tn+fn)*100,fn, tp/(tp+fp)*100, tp))
